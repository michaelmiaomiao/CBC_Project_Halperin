# %%
source("/u/project/sriram/ukbiobank/33127/ukb39967-Copy1.r",echo = T)
# Out:
# > bd <- read.table("/u/project/sriram/ukbiobank/33127/ukb39967.tab",
# +     header = TRUE, sep = "\t", nrows = 20000)
#
# > lvl.100260 <- c(1, 2, 3, 6, 7)
#
# > lbl.100260 <- c("Direct entry", "Manual entry", "Not performed",
# +     "Not performed - equipment failure", "Not performed - other reason")
#
# > bd$f.19.0.0 <- ordered(bd$f.19.0.0, levels = lvl.100260,
# +     labels = lbl.100260)
#
# > lvl.100261 <- c(-1, 1, 2, 3, 4)
#
# > lbl.100261 <- c("Question not asked due to previous answers",
# +     "Direct entry", "Manual entry of full results", "Manual measurement of weight o ..." ... [TRUNCATED]
#
# > bd$f.21.0.0 <- ordered(bd$f.21.0.0, levels = lvl.100261,
# +     labels = lbl.100261)
#
# > bd$f.21.1.0 <- ordered(bd$f.21.1.0, levels = lvl.100261,
# +     labels = lbl.100261)
#
# > bd$f.21.2.0 <- ordered(bd$f.21.2.0, levels = lvl.100261,
# +     labels = lbl.100261)
#
# > bd$f.21.3.0 <- ordered(bd$f.21.3.0, levels = lvl.100261,
# +     labels = lbl.100261)
#
# ...

# %%
print(3)
# Out:
# [1] 3

# %%
dim(bd)
# Out:
# [1] 20000 15644

# %%
missing_count=colSums(is.na(bd))

# %%
missing_count_data=as.data.frame(missing_count)

# %%
dim(missing_count_data)
# Out:
# [1] 15644     1

# %%
miss_data=cbind(as.data.frame(rownames(missing_count_data)),missing_count_data$missing_count)

# %%
colnames(miss_data)=c("var_nanme","missing_count")

# %%
miss_data[order(miss_data$missing_count),]
# Out:
#       var_nanme     missing_count
# 1     f.eid          0
# 7     f.31.0.0       0
# 8     f.34.0.0       0
# 73    f.52.0.0       0
# 74    f.53.0.0       0
# 78    f.54.0.0       0
# 82    f.55.0.0       0
# 9502  f.21003.0.0    0
# 9542  f.21022.0.0    0
# 10939 f.22700.0.0    0
# 10954 f.22702.0.0    0
# 10969 f.22704.0.0    0
# 445   f.189.0.0     26
# 448   f.670.0.0     40
# 456   f.699.0.0     40
# 5849  f.6142.0.0    40
# 503   f.864.0.0     41
# 511   f.884.0.0     41
# 519   f.904.0.0     41
# 571   f.1070.0.0    41
# 587   f.1110.0.0    41
# 607   f.1160.0.0    41
# 6217  f.6160.0.0    41
# 619   f.1190.0.0    42
# 623   f.1200.0.0    42
# 627   f.1210.0.0    42
# 631   f.1220.0.0    42
# 635   f.1239.0.0    42
# 655   f.1289.0.0    42
# 659   f.1299.0.0    42
# ⋮     ⋮             ⋮
# 13874 f.41281.0.39  20000
# 13875 f.41281.0.40  20000
# 13876 f.41281.0.41  20000
# 13877 f.41281.0.42  20000
# 13878 f.41281.0.43  20000
# 13879 f.41281.0.44  20000
# ...
