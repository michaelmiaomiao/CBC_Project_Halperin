# %%
pkg = c("dplyr","data.table","LaF")
pkgload <- lapply(pkg, require, character.only = TRUE)
# Out:
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: data.table
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# Loading required package: LaF

# %%
'/u/project/sriram/ukbiobank/33127/ukb39967.csv'
# Out:
# [1] "/u/project/sriram/ukbiobank/33127/ukb39967.csv"

# %%
## using laf first

# %%
huge_file <- '/u/project/sriram/ukbiobank/33127/ukb39967.csv'
model <- detect_dm_csv(huge_file, sep=" ", header=TRUE)

# %%
df.laf <- laf_open(model)

# %%
read_lines(df.laf, sample(1:20, 2))
# Out:
# Error in do.call(data.frame, c(x, alis)): variable names are limited to 10000 bytes
# Traceback:
#
# 1. read_lines(df.laf, sample(1:20, 2))
# 2. read_lines(df.laf, sample(1:20, 2))
# 3. .local(x, ...)
# 4. as.data.frame(df, stringsAsFactors = FALSE)
# 5. as.data.frame.list(df, stringsAsFactors = FALSE)
# 6. do.call(data.frame, c(x, alis))

# %%
########################

# %%
### use fread

# %%
bd <- fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv", header=TRUE,nrows = 2 )
bd_names <- colnames(bd)
bd_names1<-as.data.frame(strsplit(bd_names[-1],'-'))
bd_names2<-data.frame(t(bd_names1))
bd_names2<-bd_names2 %>% group_by(X1)%>% summarize(first = first(X2)) 
bd_names2$final_col<- paste(bd_names2$X1, bd_names2$first, sep="-")
final_col<-c('eid',bd_names2$final_col)
ind <- which(bd_names %in% final_col)

# %%
start_time <- Sys.time()
data_1=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =0)
end_time <- Sys.time()
end_time - start_time
# Out:
# Time difference of 17.17349 secs

# %%
birth=fread("births.csv")
dim(birth)
# Out:
# [1] 15547     5

# %%
start_time <- Sys.time()
data_1=fread("births.csv",nrow=10,skip =0)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_2=fread("births.csv",nrow=20,skip = 10,header = F)
end_time <- Sys.time()
end_time - start_time


start_time <- Sys.time()
data_3=fread("births.csv",nrow=30,skip = 20,header = F)
end_time <- Sys.time()
end_time - start_time

#start_time <- Sys.time()
#data_4=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=40000,select=ind,skip = 30000)
#end_time <- Sys.time()
#end_time - start_time

#start_time <- Sys.time()
#data=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=4000,select=ind,skip = 0)
#end_time <- Sys.time()
#end_time - start_time
# Out:
# Time difference of 0.007470131 secs
# Time difference of 0.007416725 secs
# Time difference of 0.007470369 secs

# %%
data_1 %>% dim()
data_2 %>% dim()
data_3 %>% dim()
data_1 
data_1 
data_2 
data_3
# Out:
# [1] 10  5
# [1] 20  5
# [1] 30  5
#    year month day gender births
# 1  1969 1     1   F      4046
# 2  1969 1     1   M      4440
# 3  1969 1     2   F      4454
# 4  1969 1     2   M      4548
# 5  1969 1     3   F      4548
# 6  1969 1     3   M      4994
# 7  1969 1     4   F      4440
# 8  1969 1     4   M      4520
# 9  1969 1     5   F      4192
# 10 1969 1     5   M      4198
#    year month day gender births
# 1  1969 1     1   F      4046
# 2  1969 1     1   M      4440
# 3  1969 1     2   F      4454
# 4  1969 1     2   M      4548
# 5  1969 1     3   F      4548
# 6  1969 1     3   M      4994
# 7  1969 1     4   F      4440
# 8  1969 1     4   M      4520
# 9  1969 1     5   F      4192
# 10 1969 1     5   M      4198
#    V1   V2 V3 V4 V5
# 1  1969 1   5 M  4198
# 2  1969 1   6 F  4710
# 3  1969 1   6 M  4850
# 4  1969 1   7 F  4646
# 5  1969 1   7 M  5092
# 6  1969 1   8 F  4800
# 7  1969 1   8 M  4934
# 8  1969 1   9 F  4592
# 9  1969 1   9 M  4842
# ...

# %%
start_time <- Sys.time()
data_s=fread("births.csv",nrow=30,header = F)
end_time <- Sys.time()
end_time - start_time
# Out:
# Time difference of 0.006474972 secs

# %%
data_s
# Out:
#    V1   V2    V3  V4     V5
# 1  year month day gender births
# 2  1969 1     1   F      4046
# 3  1969 1     1   M      4440
# 4  1969 1     2   F      4454
# 5  1969 1     2   M      4548
# 6  1969 1     3   F      4548
# 7  1969 1     3   M      4994
# 8  1969 1     4   F      4440
# 9  1969 1     4   M      4520
# 10 1969 1     5   F      4192
# 11 1969 1     5   M      4198
# 12 1969 1     6   F      4710
# 13 1969 1     6   M      4850
# 14 1969 1     7   F      4646
# 15 1969 1     7   M      5092
# 16 1969 1     8   F      4800
# 17 1969 1     8   M      4934
# 18 1969 1     9   F      4592
# 19 1969 1     9   M      4842
# 20 1969 1     10  F      4852
# 21 1969 1     10  M      5190
# 22 1969 1     11  F      4580
# 23 1969 1     11  M      4598
# 24 1969 1     12  F      4126
# 25 1969 1     12  M      4324
# 26 1969 1     13  F      4758
# 27 1969 1     13  M      5076
# 28 1969 1     14  F      5070
# 29 1969 1     14  M      5296
# 30 1969 1     15  F      4798

# %%
start_time <- Sys.time()
data_1=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =0)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_2=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip = 10000)
end_time <- Sys.time()
end_time - start_time


start_time <- Sys.time()
data_3=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip = 20000)
end_time <- Sys.time()
end_time - start_time
# Out:
# Time difference of 22.33108 secs
# Time difference of 16.38651 secs

# %%
data_1 %>% dim()
data_2 %>% dim()
data_3 %>% dim() 
data_1 %>% head(3)
data_2 %>% head(3) 
data_3 %>% head(3)

# %%
fwrite(data,file="data_1.csv",col.names = T)

# %%
data_1=read.csv("data_1.csv")

# %%
data_1 %>% dim()
ind %>% length()

# %%
data_1[51:53,]
# Out:
#    eid     X19.0.0 X21.0.0 X31.0.0 X34.0.0 X36.0.0 X37.0.0 X38.0.0 X39.0.0
# 51 3052132 NA      1       0       1944    2816    NA      7011    2891
# 52 5002869  1      1       1       1946    1055    NA      4147    2897
# 53 4356366  1      1       1       1949    1056    NA      1361    2068
#    X40.0.0 ⋯ X131218.0.0 X131219.0.0 X131220.0.0 X131221.0.0 X132454.0.0
# 51 1199    ⋯ NA          NA          NA          NA          NA
# 52 1187    ⋯ NA          NA          NA          NA          NA
# 53 1189    ⋯ NA          NA          NA          NA          NA
#    X132455.0.0 X132456.0.0 X132457.0.0 X132458.0.0 X132459.0.0
# 51 NA          NA          NA          NA          NA
# 52 NA          NA          NA          NA          NA
# 53 NA          NA          NA          NA          NA

# %%
# Out:
# Connection to comma separated ASCII file
#   Filename: data_1.csv
#   Column 1: name = V1, type = integer, internal type = integer

# %%
start_time <- Sys.time()
data_1=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =0)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_2=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =10000)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_3=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =20000)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_4=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =30000)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_5=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =40000)
end_time <- Sys.time()
end_time - start_time

start_time <- Sys.time()
data_6=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=10000,select=ind,skip =50000)
end_time <- Sys.time()
end_time - start_time
# Out:
# Time difference of 12.09419 secs
# Time difference of 9.437376 secs
# Time difference of 22.13428 secs
# Time difference of 22.8345 secs
# Time difference of 21.25861 secs
# Time difference of 22.56741 secs

# %%
head(data_1)
head(data_2)
head(data_3)
head(data_4)
head(data_5)
head(data_6)
dim(data_1)
dim(data_2)
dim(data_3)
dim(data_4)
dim(data_5)
dim(data_6)
# Out:
#   eid     19-0.0 21-0.0 31-0.0 34-0.0 36-0.0 37-0.0 38-0.0 39-0.0 40-0.0 ⋯
# 1 1923142  1     1      0      1966   1051   NA     1354   2028   1192   ⋯
# 2 5896937 NA     1      0      1956   3160   NA     6532   2876   1194   ⋯
# 3 2847894  3     3      1      1950   2815   NA     4582   2883   1201   ⋯
# 4 5764431  1     1      0      1947   3157   NA     1355   2896   2901   ⋯
# 5 4695056  1     1      0      1943   2817   NA     1343   2887   1199   ⋯
# 6 2456604  2     1      0      1938    163   NA      193   2871   1179   ⋯
#   131218-0.0 131219-0.0 131220-0.0 131221-0.0 132454-0.0 132455-0.0 132456-0.0
# 1            NA                    NA                    NA
# 2            NA                    NA                    NA
# 3            NA                    NA                    NA
# 4            NA                    NA                    NA
# 5            NA                    NA                    NA
# 6            NA                    NA                    NA
# ...

# %%
data=(rbind(data_1,data_2,use.names=FALSE))

# %%
data=(rbind(data,data_3,use.names=FALSE))

# %%
data=(rbind(data,data_4,use.names=FALSE))

# %%
data=(rbind(data,data_5,use.names=FALSE))

# %%
data=(rbind(data,data_6,use.names=FALSE))

# %%
fwrite(data,file="data_2.csv")

# %%
print(3)
# Out:
# [1] 3

# %%
data=NULL

for (i in 0:5){
    start_time <- Sys.time()
    data[[i+1]]=fread("/u/project/sriram/ukbiobank/33127/ukb39967.csv",nrow=100,select=ind,skip =100*i)
    end_time <- Sys.time()
    print(end_time - start_time)
    
}
# Out:
# Time difference of 0.2766728 secs
# Time difference of 0.290905 secs
# Time difference of 0.2797883 secs
# Time difference of 0.3095298 secs
# Time difference of 0.3277571 secs
# Time difference of 0.3104138 secs

# %%
bd = data[[1]]
for (i in 1:5){
    bd=rbind(bd,data[[i+1]],use.names=FALSE)
}

# %%
# Out:
#   [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [49] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# [133] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %%
head(data[[6]])
head(data[[5]])
dim(data[[6]])
dim(data[[5]])
head(data_5)
head(data_6)
# Out:
#   V1      V2 V3 V7 V8   V9   V13 V17  V21    V25  ⋯ V15635 V15636 V15637 V15638
# 1 1296239 NA 1  1  1944 3780 NA  6534 002873 1178 ⋯        NA            NA
# 2 1209338  1 3  0  1951 3157 NA  4568 002885 2903 ⋯        NA            NA
# 3 1262600  1 1  1  1939 1059 NA  1367 002874 1175 ⋯        NA            NA
# 4 3906122 NA 1  0  1944 3161 NA  7054 002893 1180 ⋯        NA            NA
# 5 1868669  1 1  1  1944 1057 NA  3110 002888 1189 ⋯        NA            NA
# 6 5680624  1 1  0  1941 3159 NA  4563 002899 2902 ⋯        NA            NA
#   V15639 V15640 V15641 V15642 V15643 V15644
# 1        NA            NA     NA     NA
# 2        NA            NA     NA     NA
# 3        NA            NA     NA     NA
# 4        NA            NA     NA     NA
# 5        NA            NA     NA     NA
# 6        NA            NA     NA     NA
#   V1      V2 V3 V7 V8   V9   V13 V17  V21  V25  ⋯ V15635 V15636 V15637 V15638
# ...
